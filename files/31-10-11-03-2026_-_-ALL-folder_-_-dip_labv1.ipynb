# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

img1= cv2.imread('image1.png')
img2= cv2.imread('image2.png')


height,width=img1.shape[:2] # to get height and width by excluding the feature chennel
img2=cv2.resize(img2,(width,height))

img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB) # essential becase cv2 read images in BGR format
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
# use cv2.imshow("title", img) or use plt.imshow(img); plt.axis('off'); plt.show

# %%
res=cv2.add(img1,img2)
cv2.imshow('image3',ImgSum)

subtracted=cv2.subtract(image1,image2)
cv2.imshow('image4',subtracted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 res=cv2.add(img1,img2)
# ----> 2 cv2.imshow('image3',ImgSum)
#       4 subtracted=cv2.subtract(image1,image2)
#       5 cv2.imshow('image4',subtracted)
#
# NameError: name 'ImgSum' is not defined

# %%
res = cv2.bitwise_and(img2,img1,mask=None)
plt.imshow(res)
plt.axis('off')
plt.title("bitwise AND")
plt.show()

res = cv2.bitwise_or(img2,img1,mask=None)
plt.imshow(res)
plt.axis('off')
plt.title("bitwise OR")
plt.show()

res = cv2.bitwise_xor(img2,img1,mask=None)
plt.imshow(res)
plt.axis('off')
plt.title("bitwise XOR")
plt.show()

res = cv2.bitwise_not(img2,mask=None)
plt.imshow(res)
plt.axis('off')
plt.title("bitwise NOT")
plt.show()

# %%
# image translation

tx = 100
ty = 70

translation_matrix = np.array([[1, 0, tx], [0, 1, ty]], dtype=np.float32)
res = cv2.warpAffine(img1, translation_matrix, (img1.shape[1], img1.shape[0]))

fig, axis = plt.subplots(1, 2, figsize=(7, 3))
axis[0].imshow(img1)
axis[1].imshow(res)

# %%
# image rotation

center = img1.shape[1] // 2, img1.shape[0] // 2
angle = 30
scale = 1

rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale)
res = cv2.warpAffine(img1, rotation_matrix,  (img1.shape[1], img1.shape[0]))

fig, axis = plt.subplots(1, 2, figsize=(7, 3))
axis[0].imshow(img1)
axis[1].imshow(res)
